# %%
from gan_torch import Mu
import numpy as np
gan = Mu(5, 0.1, 'cpu')
true_mean = np.zeros(5)
out_mean = np.ones(5) * 5
gan.dist_init(true_mean, out_mean)
gan.data_init(1000, 100)
gan.model_init()
gan.optimizer_init(0.2, 0.02, 5, 1)
gan.fit(3000)
gan.plot()
# Out:
# 100%|██████████| 3000/3000 [00:31<00:00, 96.10it/s]
