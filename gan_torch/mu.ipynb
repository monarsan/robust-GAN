# %%
from mu import Mu
import numpy as np
import matplotlib.pyplot as plt

l_momentum = [0.9, 0.8, 0.7, 0.6, 0.5]
data_dim = 100
for i in l_momentum:
    gan = Mu(data_dim, 0.1, 'cpu')
    true_mean = np.zeros(data_dim)
    out_mean = np.ones(data_dim) * 5
    gan.dist_init(true_mean, out_mean)
    gan.data_init(1000, 125)
    gan.model_init(D_model='quadratic')
    gan.optimizer_init(0.55, 0.95, 5, 1, weight_decay_d=1e-4, weight_decay_g=4e-3,
                       scheduler='exp', gamma=0.99, momentum=0.75)
    gan.fit(500)
    gan.plot()
# Out:
# 100%|██████████| 500/500 [00:06<00:00, 73.34it/s]
# 100%|██████████| 500/500 [00:07<00:00, 70.42it/s]
# 100%|██████████| 500/500 [00:06<00:00, 73.90it/s]
# 100%|██████████| 500/500 [00:07<00:00, 68.71it/s]
# 100%|██████████| 500/500 [00:07<00:00, 64.86it/s]

# %% [markdown]
# # 保存

# %%
from mu import Mu
import numpy as np
import matplotlib.pyplot as plt

# lrg = [0.004, 0.005, 0.006, 0.007]
data_dim = 50
for i in range(3):
    gan = Mu(data_dim, 0.1, 'cpu')
    true_mean = np.zeros(data_dim)
    out_mean = np.ones(data_dim) * 5
    gan.dist_init(true_mean, out_mean)
    gan.data_init(1000, 25)
    gan.model_init(D_model='quadratic')
    gan.optimizer_init(1, 0.5, 5, 1, weight_decay_d=0.025, weight_decay_g=2e-5,
                       scheduler='step', gamma=0.3, step_size=200)
    gan.fit(600)
    gan.plot()
# Out:
# 100%|██████████| 600/600 [00:25<00:00, 23.09it/s]
# 100%|██████████| 600/600 [00:25<00:00, 23.19it/s]
# 100%|██████████| 600/600 [00:26<00:00, 23.07it/s]
