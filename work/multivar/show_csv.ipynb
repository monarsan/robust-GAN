# %%
import pandas as pd

# %%
pd.read_csv("./exper_result.csv")
# Out:
#     experiment_id   loss_mean   sample_size   contamination_rate   data_dim  \
# 0               5      0.1786          1000                 0.10          2
# 1               6      0.2270          1000                 0.10          2
# 2               7      0.2795          1000                 0.10          2
# 3               8      0.1783          1000                 0.10          2
# 4               9      0.1600          1000                 0.10          2
# 5              10      0.1934          1000                 0.10          2
# 6              11      0.1510          1000                 0.10          2
# 7              12      0.3282          1000                 0.10          2
# 8              13      0.4476          1000                 0.10          2
# 9              14      0.1707          1000                 0.10          2
# 10             15      0.1907          1000                 0.10          2
# ...
