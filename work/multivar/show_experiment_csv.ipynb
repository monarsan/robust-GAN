# %%
import pandas as pd
df = pd.read_csv("./exper_result.csv")
bool = (df["experiment_id"] == 35)| (df["experiment_id"] == 46)
df[bool]
# Out:
#     experiment_id   loss_mean   sample_size   contamination_rate   data_dim  \
# 30             35      0.2449          1000                  0.1         10
# 40             46      0.2819          1000                  0.1         10
#
#      mu   mu_out   par_reg1   learn_par   dicay_par   exper_iter   optim_iter  \
# 30  5.0      0.0     0.0005        0.05         0.5           10          500
# 40  5.0      0.0     0.0050        0.05         0.5           10          500
#
#      mm_iter   init_loc_of_u   loss_std         date    time
# 30         1             0.0      0.120          NaN     NaN
# 40         1             0.0      0.155  2022-11-11    00:33

# %%
df[df[" data_dim"]==10]
# Out:
#     experiment_id   loss_mean   sample_size   contamination_rate   data_dim  \
# 30             35      0.2449          1000                  0.1         10
# 33             38      0.1489          1000                  0.1         10
# 34             40      0.2096          1000                  0.1         10
# 35             41      0.2414          1000                  0.1         10
# 37             43      0.1661          1000                  0.1         10
# 39             45      0.3204          1000                  0.1         10
# 40             46      0.2819          1000                  0.1         10
# 41             47      0.2902          1000                  0.1         10
# 42             48      0.4194          1000                  0.1         10
# 43             49      0.3853          1000                  0.1         10
# 44             50      0.3731          1000                  0.1         10
# ...
